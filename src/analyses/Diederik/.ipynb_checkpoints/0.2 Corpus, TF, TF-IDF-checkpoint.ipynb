# %%
# !python -m spacy download en_core_web_lg 
from diedfunctions import *
import warnings

# %% [markdown]
# # Import Lemmatised Wordlists

# %%
WORDLISTS_PATH = f'../../../../data/enwiki_city_pairs_lemmatised/NOUN_SPACY_LARGE_REAL_WORDS/'
data = import_lemmatised_wordlists(PATH=WORDLISTS_PATH)

# %%
data[1][2]

# %% [markdown]
# # Corpus

# %% [markdown]
# ### Create

# %%
warnings.simplefilter('ignore')

CORPUS_PATH = '../../../../data/corpus_real_words.csv'

if check_path(CORPUS_PATH):
    corpus = calculate_corpus(data=data, CORPUS_PATH=CORPUS_PATH)
# Out:
# This file already exists. Are you sure you want to override?
# Type 'Yes' to continue: Yes
#   0%|          | 0/434 [00:00<?, ?it/s]

# %% [markdown]
# ### Read (Existing File)

# %%
CORPUS_PATH = CORPUS_PATH

corpus = pd.read_csv(CORPUS_PATH)
corpus.set_index('word', inplace=True)
corpus
# Out:
#               paris_london  london_manchester  london_birmingham  \
# word
# costa                  1.0                0.0                0.0
# aboriginal             2.0                0.0                0.0
# affidavit              3.0                0.0                0.0
# gangplank              1.0                0.0                0.0
# flotilla               4.0                1.0                0.0
# ...                    ...                ...                ...
# conspectus             0.0                0.0                0.0
# pron                   0.0                0.0                0.0
# polonization           0.0                0.0                0.0
# jovy                   0.0                0.0                0.0
# laurus                 0.0                0.0                0.0
#
#               london_berlin  paris_berlin  paris_rome  london_glasgow  \
# word
# costa                   1.0           0.0         0.0             0.0
# aboriginal              0.0           0.0         0.0             0.0
# affidavit               0.0           0.0         1.0             0.0
# gangplank               1.0           1.0         0.0             0.0
# flotilla                0.0           0.0         1.0             1.0
# ...                     ...           ...         ...             ...
# conspectus              0.0           0.0         0.0             0.0
# pron                    0.0           0.0         0.0             0.0
# polonization            0.0           0.0         0.0             0.0
# jovy                    0.0           0.0         0.0             0.0
# laurus                  0.0           0.0         0.0             0.0
#
#               berlin_vienna  paris_vienna  madrid_barcelona  ...  \
# word                                                         ...
# costa                   0.0           0.0               1.0  ...
# aboriginal              0.0           0.0               0.0  ...
# affidavit               0.0           2.0               0.0  ...
# gangplank               0.0           0.0               0.0  ...
# flotilla                0.0           0.0               1.0  ...
# ...                     ...           ...               ...  ...
# conspectus              0.0           0.0               0.0  ...
# pron                    0.0           0.0               0.0  ...
# polonization            0.0           0.0               0.0  ...
# jovy                    0.0           0.0               0.0  ...
# laurus                  0.0           0.0               0.0  ...
#
#               katowice_copenhagen  athens_katowice  milan_katowice  \
# word
# costa                         0.0              0.0             0.0
# aboriginal                    0.0              0.0             0.0
# affidavit                     0.0              0.0             0.0
# gangplank                     0.0              0.0             0.0
# flotilla                      0.0              0.0             0.0
# ...                           ...              ...             ...
# conspectus                    0.0              0.0             0.0
# pron                          0.0              0.0             0.0
# polonization                  0.0              0.0             0.0
# jovy                          0.0              0.0             0.0
# laurus                        0.0              0.0             0.0
#
#               naples_katowice  katowice_manchester  lisbon_katowice  \
# word
# costa                     0.0                  0.0              0.0
# aboriginal                0.0                  0.0              0.0
# affidavit                 0.0                  0.0              0.0
# gangplank                 0.0                  0.0              0.0
# flotilla                  0.0                  0.0              0.0
# ...                       ...                  ...              ...
# conspectus                0.0                  0.0              0.0
# pron                      0.0                  0.0              0.0
# polonization              0.0                  0.0              0.0
# jovy                      0.0                  0.0              0.0
# laurus                    0.0                  0.0              0.0
#
#               katowice_glasgow  birmingham_katowice  katowice_turin  \
# word
# costa                      0.0                  0.0             0.0
# aboriginal                 0.0                  0.0             0.0
# affidavit                  0.0                  0.0             0.0
# gangplank                  0.0                  0.0             0.0
# flotilla                   0.0                  0.0             0.0
# ...                        ...                  ...             ...
# conspectus                 0.0                  0.0             0.0
# pron                       0.0                  0.0             0.0
# polonization               0.0                  0.0             0.0
# jovy                       0.0                  0.0             0.0
# laurus                     0.0                  0.0             0.0
#
#               katowice_valencia
# word
# costa                         0
# aboriginal                    0
# affidavit                     0
# gangplank                     0
# flotilla                      0
# ...                         ...
# conspectus                    0
# pron                          0
# polonization                  0
# jovy                          0
# laurus                        0
#
# [33530 rows x 434 columns]

# %% [markdown]
# # Term Frequency Matrix

# %% [markdown]
# ### Create

# %%
TF_PATH = '../../../../data/tf_real_words.csv'

if check_path(TF_PATH):
    tf = calculate_tf(corpus, OUTPUT_PATH=TF_PATH, include_idf=False)
# Out:
#   0%|          | 0/33530 [00:00<?, ?it/s]
# Saved results to '../../../../data/tf_real_words.csv'.

# %% [markdown]
# ### Read (Existing File)

# %%
TF_PATH = TF_PATH

tf = pd.read_csv(TF_PATH)
tf.set_index('word', inplace=True)

# %%
tf.sort_values(by="paris_london", ascending=False)[:25]
# Out:
#             paris_london  london_manchester  london_birmingham  london_berlin  \
# word
# art             0.401924           0.131577           0.111006       0.235692
# year            0.363687           0.232845           0.195526       0.199562
# work            0.280164           0.101808           0.106890       0.157759
# time            0.263987           0.174836           0.133692       0.139644
# city            0.217477           0.169799           0.156168       0.128496
# exhibition      0.157669           0.037503           0.030706       0.073654
# world           0.157240           0.059897           0.054026       0.116552
# opera           0.153808           0.028510           0.023320       0.148203
# school          0.153379           0.124831           0.112483       0.079228
# music           0.139469           0.107923           0.095600       0.121628
# company         0.136773           0.118626           0.121241       0.069673
# artist          0.127765           0.035345           0.034399       0.069971
# film            0.126295           0.041281           0.036298       0.163631
# gallery         0.126295           0.055131           0.046850       0.079128
# member          0.121637           0.068531           0.055819       0.065492
# museum          0.112691           0.025632           0.017622       0.086792
# festival        0.112691           0.071139           0.063100       0.179954
# war             0.108401           0.039572           0.028490       0.070568
# society         0.102947           0.065114           0.059618       0.046880
# painting        0.099638           0.021495           0.014562       0.034936
# family          0.096146           0.047486           0.037248       0.044590
# collection      0.094246           0.023383           0.012451       0.050761
# tour            0.091060           0.110981           0.080089       0.061809
# service         0.089160           0.153611           0.173473       0.036528
# life            0.088547           0.034266           0.026169       0.040211
#
#             paris_berlin  paris_rome  london_glasgow  berlin_vienna  \
# word
# art             0.259468    0.251982        0.164422       0.164915
# year            0.230056    0.257267        0.168496       0.195060
# work            0.186342    0.184653        0.098450       0.139329
# time            0.148469    0.143537        0.115990       0.119696
# city            0.132051    0.116372        0.108860       0.108423
# exhibition      0.087429    0.074622        0.044246       0.051425
# world           0.095588    0.065744        0.044925       0.079291
# opera           0.167506    0.073037        0.017087       0.314123
# school          0.083803    0.069020        0.094715       0.061685
# music           0.102538    0.057816        0.057372       0.116276
# company         0.056507    0.027164        0.100373       0.042559
# artist          0.073731    0.074516        0.043001       0.052945
# film            0.121676    0.054540        0.048772       0.077011
# gallery         0.053485    0.040905        0.054883       0.025079
# member          0.081587    0.065638        0.062351       0.074858
# museum          0.079976    0.044393        0.023424       0.052945
# festival        0.134770    0.045238        0.061220       0.131856
# war             0.082494    0.047458        0.034401       0.075237
# society         0.037571    0.031815        0.074573       0.031032
# painting        0.055802    0.099250        0.025008       0.025586
# family          0.062853    0.059190        0.037682       0.052692
# collection      0.053586    0.036677        0.017087       0.030399
# tour            0.049456    0.037840        0.093810       0.042179
# service         0.040995    0.036677        0.119158       0.038252
# life            0.042305    0.046612        0.028856       0.031159
#
#             paris_vienna  madrid_barcelona  ...  katowice_copenhagen  \
# word                                        ...
# art             0.196373          0.078321  ...             0.000000
# year            0.204378          0.241527  ...             0.030303
# work            0.143340          0.070687  ...             0.007576
# time            0.125954          0.194198  ...             0.007576
# city            0.094559          0.134656  ...             0.007576
# exhibition      0.080926          0.035878  ...             0.000000
# world           0.082927          0.076031  ...             0.015152
# opera           0.276173          0.056336  ...             0.015152
# school          0.068168          0.034656  ...             0.007576
# music           0.095310          0.036641  ...             0.007576
# company         0.044903          0.048855  ...             0.000000
# artist          0.054159          0.022748  ...             0.000000
# film            0.041151          0.043817  ...             0.000000
# gallery         0.031770          0.015878  ...             0.000000
# member          0.058036          0.066107  ...             0.007576
# museum          0.057161          0.023664  ...             0.000000
# festival        0.098186          0.062595  ...             0.015152
# war             0.061413          0.049313  ...             0.000000
# society         0.031895          0.018473  ...             0.007576
# painting        0.045403          0.020153  ...             0.000000
# family          0.060913          0.027634  ...             0.000000
# collection      0.035147          0.016031  ...             0.000000
# tour            0.039149          0.044733  ...             0.030303
# service         0.036273          0.058168  ...             0.000000
# life            0.039024          0.018015  ...             0.000000
#
#             athens_katowice  milan_katowice  naples_katowice  \
# word
# art                0.000000        0.000000         0.133333
# year               0.000000        0.000000         0.016667
# work               0.000000        0.000000         0.016667
# time               0.037975        0.014085         0.000000
# city               0.012658        0.014085         0.016667
# exhibition         0.000000        0.000000         0.000000
# world              0.012658        0.000000         0.000000
# opera              0.000000        0.028169         0.000000
# school             0.000000        0.000000         0.016667
# music              0.000000        0.000000         0.000000
# company            0.000000        0.014085         0.000000
# artist             0.000000        0.000000         0.000000
# film               0.000000        0.000000         0.000000
# gallery            0.000000        0.000000         0.050000
# member             0.000000        0.000000         0.000000
# museum             0.000000        0.000000         0.116667
# festival           0.000000        0.028169         0.000000
# war                0.012658        0.000000         0.000000
# society            0.000000        0.000000         0.016667
# painting           0.000000        0.000000         0.000000
# family             0.000000        0.000000         0.000000
# collection         0.000000        0.000000         0.083333
# tour               0.050633        0.000000         0.000000
# service            0.025316        0.000000         0.000000
# life               0.000000        0.000000         0.000000
#
#             katowice_manchester  lisbon_katowice  katowice_glasgow  \
# word
# art                    0.000000         0.000000           0.00000
# year                   0.018868         0.000000           0.00000
# work                   0.000000         0.000000           0.00000
# time                   0.037736         0.020408           0.02381
# city                   0.000000         0.040816           0.00000
# exhibition             0.000000         0.000000           0.00000
# world                  0.094340         0.020408           0.00000
# opera                  0.000000         0.000000           0.00000
# school                 0.000000         0.000000           0.00000
# music                  0.000000         0.000000           0.00000
# company                0.018868         0.000000           0.00000
# artist                 0.000000         0.000000           0.00000
# film                   0.000000         0.000000           0.00000
# gallery                0.000000         0.000000           0.00000
# member                 0.000000         0.000000           0.00000
# museum                 0.000000         0.000000           0.00000
# festival               0.000000         0.040816           0.00000
# war                    0.000000         0.000000           0.00000
# society                0.000000         0.000000           0.00000
# painting               0.000000         0.000000           0.00000
# family                 0.000000         0.000000           0.00000
# collection             0.000000         0.000000           0.00000
# tour                   0.000000         0.081633           0.00000
# service                0.018868         0.020408           0.00000
# life                   0.000000         0.000000           0.00000
#
#             birmingham_katowice  katowice_turin  katowice_valencia
# word
# art                    0.000000        0.000000           0.000000
# year                   0.030303        0.027778           0.028571
# work                   0.000000        0.027778           0.000000
# time                   0.000000        0.000000           0.000000
# city                   0.030303        0.000000           0.000000
# exhibition             0.000000        0.000000           0.000000
# world                  0.000000        0.000000           0.000000
# opera                  0.000000        0.027778           0.028571
# school                 0.000000        0.000000           0.000000
# music                  0.000000        0.027778           0.000000
# company                0.000000        0.000000           0.000000
# artist                 0.000000        0.000000           0.000000
# film                   0.000000        0.000000           0.000000
# gallery                0.000000        0.000000           0.000000
# member                 0.000000        0.000000           0.000000
# museum                 0.000000        0.000000           0.000000
# festival               0.000000        0.000000           0.028571
# war                    0.000000        0.000000           0.000000
# society                0.000000        0.000000           0.000000
# painting               0.000000        0.000000           0.000000
# family                 0.000000        0.000000           0.000000
# collection             0.000000        0.000000           0.000000
# tour                   0.030303        0.111111           0.000000
# service                0.000000        0.000000           0.000000
# life                   0.000000        0.000000           0.000000
#
# [25 rows x 434 columns]

# %% [markdown]
# # Term Frequency - Inverse Document Frequency

# %% [markdown]
# ### Create

# %%
TFIDF_PATH = '../../../../data/new_tfidf.csv'

if check_path(TFIDF_PATH):
    tfidf = calculate_tf(corpus, OUTPUT_PATH=TFIDF_PATH, include_idf=True)

# %% [markdown]
# ### Read (Existing File)

# %%
TFIDF_PATH = '../../../../data/new_tfidf.csv'

tfidf = pd.read_csv(TFIDF_PATH)

# %% [markdown]
# <hr>
# <hr>
# <hr>
# <hr>
# <hr>
# <hr>
# <hr>
# <hr>
# <!-- <br>
# <br>
# <br>
# <br>
# <br>
# <br> -->
# <div style="height: 500px;"></div>

# %%
https://www.youtube.com/shorts/q8Ook-3h9DQ

# %%
# import pandas
# import math

# CORPUS_PATH = f'../../../../data/corpus.csv'
# TF_CSV_PATH = f'../../../../data/tf.csv'

    

# def calculate_tf(corpus='', OUTPUT_PATH='', include_idf=False) -> tuple:
#     """

#     Calculates the tfidf per speaker per conference

#     :return: ...

#     """
    
#     if not isinstance(corpus, pd.DataFrame):
#         raise Exception("Corpus is required as input (can use calculate_corpus to create one.)")
        
#     if not OUTPUT_PATH:
#         OUTPUT_PATH = './new_tfidf.csv' if include_idf else './new_tf.csv'
        
#     try:
#         corpus.set_index('word', inplace=True)
#     except:
#         pass
    
#     tf_idf = {k: [] for k in corpus.columns}

#     # Create Dataframe with Relative Word Frequencies
#     for index, row in tqdm(corpus.iterrows(), total=len(corpus)):
#         docs_with = np.count_nonzero(row)

#         for colname, count in row.items():
#             total_uniques = np.count_nonzero(corpus[colname])
#             tf = count / total_uniques
#             result = tf
            
#             if include_idf:
#                 idf = math.log(len(corpus.columns) / docs_with)
#                 result *= idf

#             tf_idf[colname].append(result)

#     tf_idf_df = pd.DataFrame.from_dict(tf_idf)
#     tf_idf_df.set_index(corpus.index, inplace=True)

#     tf_idf_df.to_csv(OUTPUT_PATH)
#     print(f"Saved results to '{OUTPUT_PATH}'.")

#     return tf_idf_df
