# %%
import pandas as pd

# %%
df =  pd.read_csv("../../../../../data/clean/deliverable_435city_pairs_both_methods_with_education_final_normalised.csv") 
# df['merged_POS'] = df['merged_POS'].apply(literal_eval)

# %%
df[df['city_pair'].isin(['barcelona_manchester', 'paris_milan', 'warsaw_prague'])] #.value_counts(normalize=True)
# Out:
#                 city_pair  paragraphs  lemmatised_paragraph_length  \
# 36   barcelona_manchester         694                    41.492795
# 349           paris_milan        2222                    32.068407
# 428         warsaw_prague         601                    37.073211
#
#      same_categorisation_raw  same_categorisation_percentage  \
# 36                       676                        0.974063
# 349                     1920                        0.864086
# 428                      548                        0.911814
#
#     lda_dominant_category embedding_dominant_category   lda_art  \
# 36              lda_sport                       sport  0.017291
# 349               lda_art                         art  0.341134
# 428         lda_diplomacy                   diplomacy  0.084859
#
#      embedding_art  lda_diplomacy  embedding_diplomacy  lda_education  \
# 36        0.014409       0.014409             0.024496       0.017291
# ...

# %%
df2 =  pd.read_csv("../../../../../data/clean/deliverable_435city_pairs_both_methods_with_education_final.csv") 
# df['merged_POS'] = df['merged_POS'].apply(literal_eval)

# %%
df2[df2['city_pair'].isin(['barcelona_manchester', 'paris_milan', 'warsaw_prague'])]
# Out:
#                 city_pair  paragraphs  lemmatised_paragraph_length  \
# 36   barcelona_manchester         694                    41.492795
# 349           paris_milan        2222                    32.068407
# 428         warsaw_prague         601                    37.073211
#
#      same_categorisation_raw  same_categorisation_percentage  \
# 36                       676                        0.974063
# 349                     1920                        0.864086
# 428                      548                        0.911814
#
#     lda_dominant_category embedding_dominant_category  lda_art  embedding_art  \
# 36              lda_sport                       sport       12             10
# 349               lda_art                         art      758            637
# 428         lda_diplomacy                   diplomacy       51             40
#
#      lda_diplomacy  embedding_diplomacy  lda_education  embedding_education  \
# ...

# %% [markdown]
# sport 330 14.85
#
# diplomacy 286 12.87
# transportation 261 11.75
#
# education 65 10.82
#
# transportatin 97
